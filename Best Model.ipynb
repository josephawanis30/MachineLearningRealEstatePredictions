# %%
# Importing necessary libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn import tree
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler,OneHotEncoder
import pickle

# %%
# Reading in the data
housing_df = pd.read_csv("combined_data_clean.csv")
housing_df.head()
# Out:
#    id   Price              Address    zip  status      mls  \
# 0   1  427167  3231 W MARYLAND AVE  85017  Active  6395749
# 1   2  400000     5109 E THOMAS RD  85018  Active  6243667
# 2   3  399900    8020 W STELLA AVE  85303  Active  6384821
# 3   4  349000      6944 W Verde LN  85033  Active  6395738
# 4   5  419000  4105 W PASADENA AVE  85019  Active  6395732
#
#                 Subdivision  Year Built  Bedrooms  Bathrooms  Approx SQFT  \
# 0  WEST PLAZA 6 LOT 614-787        1958         3        2.0       1302.0
# 1            PAPAGO VILLAGE        1943         0        0.0       1358.0
# 2                  SHALIMAR        1997         3        2.0       1505.0
# 3   MARYVALE TERRACE NO. 49        1983         3        3.0       1514.0
# 4            TU-DOR ESTATES        1971         4        2.0       1908.0
#
#    CrimeRate
# 0        4.1
# 1        2.2
# 2        0.0
# 3        3.0
# 4        2.5

# %%
# Check datatypes and make conversions if necessary
housing_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2265 entries, 0 to 2264
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   id           2265 non-null   int64
#  1   Price        2265 non-null   int64
#  2   Address      2265 non-null   object
#  3   zip          2265 non-null   int64
#  4   status       2265 non-null   object
#  5   mls          2265 non-null   int64
#  6   Subdivision  2261 non-null   object
#  7   Year Built   2265 non-null   int64
#  8   Bedrooms     2265 non-null   int64
#  9   Bathrooms    2265 non-null   float64
#  10  Approx SQFT  2265 non-null   float64
#  11  CrimeRate    2205 non-null   float64
# dtypes: float64(3), int64(6), object(3)
# memory usage: 212.5+ KB

# %%
# Interpolation
housing_df1 = housing_df.fillna(2.5)

# %%
# Checking the data again
housing_df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2265 entries, 0 to 2264
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   id           2265 non-null   int64
#  1   Price        2265 non-null   int64
#  2   Address      2265 non-null   object
#  3   zip          2265 non-null   int64
#  4   status       2265 non-null   object
#  5   mls          2265 non-null   int64
#  6   Subdivision  2265 non-null   object
#  7   Year Built   2265 non-null   int64
#  8   Bedrooms     2265 non-null   int64
#  9   Bathrooms    2265 non-null   float64
#  10  Approx SQFT  2265 non-null   float64
#  11  CrimeRate    2265 non-null   float64
# dtypes: float64(3), int64(6), object(3)
# memory usage: 212.5+ KB

# %%
education_df = pd.read_csv("education_by_zip.csv")
education_df.head()
education_df.rename(columns={'Zip':'zip'},inplace=True)
education_df.head()
# Out:
#      zip Elem_School_District  Hightest_Rated_School
# 0  85003   Phoenix Elementary                  94.44
# 1  85004   Phoenix Elementary                  94.44
# 2  85006   Phoenix Elementary                  94.44
# 3  85007   Phoenix Elementary                  94.44
# 4  85008                Balsz                  81.79

# %%
housing_df1.drop_duplicates()
# Out:
#         id   Price               Address    zip  status      mls  \
# 0        1  427167   3231 W MARYLAND AVE  85017  Active  6395749
# 1        2  400000      5109 E THOMAS RD  85018  Active  6243667
# 2        3  399900     8020 W STELLA AVE  85303  Active  6384821
# 3        4  349000       6944 W Verde LN  85033  Active  6395738
# 4        5  419000   4105 W PASADENA AVE  85019  Active  6395732
# ...    ...     ...                   ...    ...     ...      ...
# 2260  2311  600000  3402 E CAROL ANN WAY  85032  Closed  6368329
# 2261  2312  375000   739 E Constance WAY  85042  Closed  6358973
# 2262  2313  365000      7301 W CHERYL DR  85345  Closed  6365681
# 2263  2314  529000     4637 E GRANADA RD  85008  Closed  6354718
# 2264  2315  460000       2016 W HOLLY ST  85009  Closed  6362564
#
#                    Subdivision  Year Built  Bedrooms  Bathrooms  Approx SQFT  \
# 0     WEST PLAZA 6 LOT 614-787        1958         3        2.0       1302.0
# 1               PAPAGO VILLAGE        1943         0        0.0       1358.0
# 2                     SHALIMAR        1997         3        2.0       1505.0
# 3      MARYVALE TERRACE NO. 49        1983         3        3.0       1514.0
# 4               TU-DOR ESTATES        1971         4        2.0       1908.0
# ...                        ...         ...       ...        ...          ...
# 2260               BELLA TERRA        1981         3        2.0       2012.0
# 2261        VILLAGES AT VERONA        2016         3        2.5       1499.0
# 2262            SUNTOWN UNIT 2        1972         3        2.0       1581.0
# 2263                RANCHO MIO        1953         3        2.0       1710.0
# 2264                    VENICE        1953         3        2.0       1145.0
#
#       CrimeRate
# 0           4.1
# 1           2.2
# 2           0.0
# 3           3.0
# 4           2.5
# ...         ...
# 2260        3.2
# 2261        2.9
# 2262        0.0
# 2263        4.5
# 2264        4.0
#
# [2265 rows x 12 columns]

# %%
merged_df=housing_df1.merge(education_df, how='left', on='zip')
merged_df
# Out:
#         id   Price               Address    zip  status      mls  \
# 0        1  427167   3231 W MARYLAND AVE  85017  Active  6395749
# 1        2  400000      5109 E THOMAS RD  85018  Active  6243667
# 2        3  399900     8020 W STELLA AVE  85303  Active  6384821
# 3        4  349000       6944 W Verde LN  85033  Active  6395738
# 4        5  419000   4105 W PASADENA AVE  85019  Active  6395732
# ...    ...     ...                   ...    ...     ...      ...
# 2260  2311  600000  3402 E CAROL ANN WAY  85032  Closed  6368329
# 2261  2312  375000   739 E Constance WAY  85042  Closed  6358973
# 2262  2313  365000      7301 W CHERYL DR  85345  Closed  6365681
# 2263  2314  529000     4637 E GRANADA RD  85008  Closed  6354718
# 2264  2315  460000       2016 W HOLLY ST  85009  Closed  6362564
#
#                    Subdivision  Year Built  Bedrooms  Bathrooms  Approx SQFT  \
# 0     WEST PLAZA 6 LOT 614-787        1958         3        2.0       1302.0
# 1               PAPAGO VILLAGE        1943         0        0.0       1358.0
# 2                     SHALIMAR        1997         3        2.0       1505.0
# 3      MARYVALE TERRACE NO. 49        1983         3        3.0       1514.0
# 4               TU-DOR ESTATES        1971         4        2.0       1908.0
# ...                        ...         ...       ...        ...          ...
# 2260               BELLA TERRA        1981         3        2.0       2012.0
# 2261        VILLAGES AT VERONA        2016         3        2.5       1499.0
# 2262            SUNTOWN UNIT 2        1972         3        2.0       1581.0
# 2263                RANCHO MIO        1953         3        2.0       1710.0
# 2264                    VENICE        1953         3        2.0       1145.0
#
#       CrimeRate     Elem_School_District  Hightest_Rated_School
# 0           4.1                 Alhambra                 100.04
# 1           2.2                Creighton                  75.80
# 2           0.0               Cartwright                  95.89
# 3           3.0               Cartwright                  95.89
# 4           2.5                 Alhambra                 100.04
# ...         ...                      ...                    ...
# 2260        3.2  Paradise Valley Unified                  99.97
# 2261        2.9                Roosevelt                  76.54
# 2262        0.0               Pendergast                  85.28
# 2263        4.5                    Balsz                  81.79
# 2264        4.0                   Murphy                  65.70
#
# [2265 rows x 14 columns]

# %%
new_housing_df=merged_df.drop(columns=['mls','Address','id','Subdivision','status','Elem_School_District'
                                      ],axis=1)
new_housing_df
# Out:
#        Price    zip  Year Built  Bedrooms  Bathrooms  Approx SQFT  CrimeRate  \
# 0     427167  85017        1958         3        2.0       1302.0        4.1
# 1     400000  85018        1943         0        0.0       1358.0        2.2
# 2     399900  85303        1997         3        2.0       1505.0        0.0
# 3     349000  85033        1983         3        3.0       1514.0        3.0
# 4     419000  85019        1971         4        2.0       1908.0        2.5
# ...      ...    ...         ...       ...        ...          ...        ...
# 2260  600000  85032        1981         3        2.0       2012.0        3.2
# 2261  375000  85042        2016         3        2.5       1499.0        2.9
# 2262  365000  85345        1972         3        2.0       1581.0        0.0
# 2263  529000  85008        1953         3        2.0       1710.0        4.5
# 2264  460000  85009        1953         3        2.0       1145.0        4.0
#
#       Hightest_Rated_School
# 0                    100.04
# 1                     75.80
# 2                     95.89
# 3                     95.89
# 4                    100.04
# ...                     ...
# 2260                  99.97
# 2261                  76.54
# 2262                  85.28
# 2263                  81.79
# 2264                  65.70
#
# [2265 rows x 8 columns]

# %%
# creating a new csv file named ml_model.
new_housing_df.to_csv("ml_model_data.csv", index=False)

# %%
# Split our preprocessed data into our features and target arrays
#y = new_housing_df["Price"].values
y = new_housing_df["Price"]
#X = new_housing_df.drop(["Price"],axis=1).values
X = new_housing_df.drop(["Price"],axis=1)
X
# Out:
#         zip  Year Built  Bedrooms  Bathrooms  Approx SQFT  CrimeRate  \
# 0     85017        1958         3        2.0       1302.0        4.1
# 1     85018        1943         0        0.0       1358.0        2.2
# 2     85303        1997         3        2.0       1505.0        0.0
# 3     85033        1983         3        3.0       1514.0        3.0
# 4     85019        1971         4        2.0       1908.0        2.5
# ...     ...         ...       ...        ...          ...        ...
# 2260  85032        1981         3        2.0       2012.0        3.2
# 2261  85042        2016         3        2.5       1499.0        2.9
# 2262  85345        1972         3        2.0       1581.0        0.0
# 2263  85008        1953         3        2.0       1710.0        4.5
# 2264  85009        1953         3        2.0       1145.0        4.0
#
#       Hightest_Rated_School
# 0                    100.04
# 1                     75.80
# 2                     95.89
# 3                     95.89
# 4                    100.04
# ...                     ...
# 2260                  99.97
# 2261                  76.54
# 2262                  85.28
# 2263                  81.79
# 2264                  65.70
#
# [2265 rows x 7 columns]

# %%
len(X['zip'].unique())
# Out:
# 47

# %%
len(X['CrimeRate'].unique())
# Out:
# 26

# %%
len(X['Hightest_Rated_School'].unique())
# Out:
# 17

# %%
# df=pd.DataFrame(columns=['zip','CrimeRate','Hightest_Rated_School'])
# for zipcode in X['zip'].unique():
#     df.append(X.loc[X['zip']=='zipcode'])

# %%
# loaded_model = pickle.load(open('housepricepredictions.h5','rb'))

# %%
# loaded_model.predict(X)
# Out:
# array([397520.81063452, 475684.74019872, 404312.77569586, ...,
#        391185.49741305, 548358.21278111, 408188.65531644])

# %%
# df_zip=X.loc[(X['zip']==zip)]

# %%
# df_zip

# %%
# ZipCrimeSchool=pd.concat([zipcode_crime_school['zip'],zipcode_crime_school['CrimeRate'],zipcode_crime_school['Hightest_Rated_School']],axis=1).unique()
# pd.DataFrame(ZipCrimeSchool)

# %%
# i=0
# df=pd.DataFrame()
# for col in zipcode_crime_school:
   
#     print(col)
   
#     df[i]=zipcode_crime_school[f'{col}'].unique()
#     i+=1
# df

# %%
zip_list=[]
zip_crime_school={}
for zip in X['zip']:
    if zip not in zip_list:
        zip_list.append(zip)
   
        zip_crime_school['school_rating']=X.groupby(['zip']).mean()['Hightest_Rated_School'] 
        zip_crime_school['crime_rate']=X.groupby(['zip']).mean()['CrimeRate']

zip_school_crime_df = pd.DataFrame.from_dict(zip_crime_school)
zip_school_crime_df.head(10)
# Out:
#        school_rating  crime_rate
# zip
# 85003          94.44         1.1
# 85004          94.44         1.2
# 85006          94.44         1.9
# 85007          94.44         1.6
# 85008          81.79         4.5
# 85009          65.70         4.0
# 85012          72.93         0.6
# 85013          72.93         2.0
# 85014          97.13         1.9
# 85015         100.04         5.5

# %%
new_zip_crime_school=pd.DataFrame.to_dict(zip_school_crime_df)

# %%
new_zip_crime_school
# Out:
# {'school_rating': {85003: 94.44,
#   85004: 94.44,
#   85006: 94.44,
#   85007: 94.44,
#   85008: 81.79,
#   85009: 65.7,
#   85012: 72.93,
#   85013: 72.93,
#   85014: 97.13000000000001,
#   85015: 100.04000000000002,
#   85016: 97.13,
#   85017: 100.04,
#   85018: 75.8,
#   85019: 100.04,
#   85020: 97.13,
#   85021: 91.9,
#   85022: 99.97,
#   85023: 91.9,
#   85028: 99.97,
#   85029: 91.9,
#   85031: 100.04,
#   85032: 99.97,
#   85033: 95.89,
#   85034: 68.34,
#   85035: 95.89,
#   85037: 85.28,
#   85040: 76.54,
#   85041: 76.54,
#   85042: 76.54,
#   85043: 76.86,
#   85051: 91.9,
#   85053: 91.9,
#   85250: 101.35,
#   85251: 101.35,
#   85254: 99.97,
#   85257: 101.34999999999998,
#   85258: 101.34999999999998,
#   85281: 94.49,
#   85282: 94.49,
#   85301: 100.04,
#   85302: 91.9,
#   85303: 95.89,
#   85304: 91.9,
#   85305: 85.28,
#   85306: 91.9,
#   85339: 94.47,
#   85345: 85.28},
#  'crime_rate': {85003: 1.1,
#   85004: 1.2,
#   85006: 1.9,
#   85007: 1.6,
#   85008: 4.5,
#   85009: 4.0,
#   85012: 0.6,
#   85013: 2.0,
#   85014: 1.9,
#   85015: 5.5,
#   85016: 3.2,
#   85017: 4.1,
#   85018: 2.2,
#   85019: 2.5,
#   85020: 2.1,
#   85021: 2.8,
#   85022: 2.6,
#   85023: 3.4,
#   85028: 0.6,
#   85029: 3.3,
#   85031: 2.4,
#   85032: 3.1999999999999997,
#   85033: 3.0,
#   85034: 1.8999999999999997,
#   85035: 3.3,
#   85037: 1.9,
#   85040: 2.8,
#   85041: 4.5,
#   85042: 2.9,
#   85043: 3.2,
#   85051: 4.3,
#   85053: 1.5,
#   85250: 2.5,
#   85251: 0.0,
#   85254: 1.1,
#   85257: 2.5,
#   85258: 0.0,
#   85281: 0.0,
#   85282: 0.0,
#   85301: 0.0,
#   85302: 0.0,
#   85303: 0.0,
#   85304: 0.2,
#   85305: 2.5,
#   85306: 0.3,
#   85339: 2.0,
#   85345: 0.0}}

# %%
zip_crime_school
# Out:
# {'school_rating': zip
#  85003     94.44
#  85004     94.44
#  85006     94.44
#  85007     94.44
#  85008     81.79
#  85009     65.70
#  85012     72.93
#  85013     72.93
#  85014     97.13
#  85015    100.04
#  85016     97.13
#  85017    100.04
#  85018     75.80
#  85019    100.04
#  85020     97.13
#  85021     91.90
#  85022     99.97
#  85023     91.90
#  85028     99.97
#  85029     91.90
#  85031    100.04
#  85032     99.97
#  85033     95.89
#  85034     68.34
#  85035     95.89
#  85037     85.28
#  85040     76.54
#  85041     76.54
#  85042     76.54
#  85043     76.86
#  85051     91.90
#  85053     91.90
#  85250    101.35
#  85251    101.35
#  85254     99.97
#  85257    101.35
#  85258    101.35
#  85281     94.49
#  85282     94.49
#  85301    100.04
#  85302     91.90
#  85303     95.89
#  85304     91.90
#  85305     85.28
#  85306     91.90
#  85339     94.47
#  85345     85.28
#  Name: Hightest_Rated_School, dtype: float64,
#  'crime_rate': zip
#  85003    1.1
#  85004    1.2
#  85006    1.9
#  85007    1.6
#  85008    4.5
#  85009    4.0
#  85012    0.6
#  85013    2.0
#  85014    1.9
#  85015    5.5
#  85016    3.2
#  85017    4.1
#  85018    2.2
#  85019    2.5
#  85020    2.1
#  85021    2.8
#  85022    2.6
#  85023    3.4
#  85028    0.6
#  85029    3.3
#  85031    2.4
#  85032    3.2
#  85033    3.0
#  85034    1.9
#  85035    3.3
#  85037    1.9
#  85040    2.8
#  85041    4.5
#  85042    2.9
#  85043    3.2
#  85051    4.3
#  85053    1.5
#  85250    2.5
#  85251    0.0
#  85254    1.1
#  85257    2.5
#  85258    0.0
#  85281    0.0
#  85282    0.0
#  85301    0.0
#  85302    0.0
#  85303    0.0
#  85304    0.2
#  85305    2.5
#  85306    0.3
#  85339    2.0
#  85345    0.0
#  Name: CrimeRate, dtype: float64}

# %%
# Split the preprocessed data into a training and testing dataset
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=78)

# %%
clf = RandomForestRegressor(n_estimators = 7272, min_samples_split = 2, min_samples_leaf = 2, max_leaf_nodes = 700,
                            max_features = 'sqrt', max_depth = 20, bootstrap = False, random_state = 78)
clf.fit(X_train, y_train)
# Out:
# RandomForestRegressor(bootstrap=False, max_depth=20, max_features='sqrt',
#                       max_leaf_nodes=700, min_samples_leaf=2, n_estimators=7272,
#                       random_state=78)

# %%
print(f'Training Score: {clf.score(X_train, y_train)}')
print(f'Testing Score: {clf.score(X_test, y_test)}')
# Out:
# Training Score: 0.9474316769662338
# Testing Score: 0.7423633263193231

# %%
predicted=clf.predict(X_test)
predicted
# Out:
# array([469737.48264962, 460664.51582967, 460112.73349462, 764904.30900545,
#        371591.23119069, 657427.34954751, 530245.58958752, 564159.82718425,
#        370121.31097794, 346363.32708211, 517462.99009222, 452445.30797528,
#        411606.47454412, 359154.0678087 , 619772.39546564, 506984.09683232,
#        557244.70526105, 705066.39396984, 324104.15432829, 577186.60076934,
#        882700.22810735, 519197.18346372, 461636.2726227 , 443051.41688147,
#        724273.63601574, 345025.29889333, 758942.48143309, 506125.63240382,
#        400052.40209511, 673915.74905954, 377730.92526885, 786935.70995794,
#        376668.65324197, 407621.23501696, 548944.90357354, 664499.2101314 ,
#        313373.96169135, 325689.09733761, 364547.7260488 , 488929.4793687 ,
#        517753.31036994, 709177.73810441, 637136.51602939, 394160.01076291,
#        794440.25726984, 368084.58778975, 367840.27467795, 424720.53037386,
#        494844.60611873, 376154.08324101, 293238.83830938, 341772.47171325,
#        466669.45111144, 429607.65515992, 611258.58971952, 803732.03444721,
#        556112.69995917, 387958.04077161, 744046.00247985, 516342.0888361 ,
#        629553.75313108, 415172.0643768 , 818591.3274619 , 480225.30430551,
#        327561.43726144, 348980.34939672, 659464.02226868, 444744.25318835,
#        461754.35328032, 393236.31117066, 857807.25664506, 509362.38250852,
#        725745.39385292, 400342.75889842, 457916.50092564, 627496.06652791,
#        668754.0340377 , 557826.89349025, 383505.62101111, 448385.18594788,
#        362756.79608224, 880634.40157893, 597180.63659317, 391415.3509211 ,
#        489765.82729908, 427287.37765546, 463278.5168429 , 583167.40498023,
#        629499.52131857, 716369.93469096, 402388.37058524, 731934.54334509,
#        368681.9445818 , 679182.11005189, 505637.51144168, 491092.36718814,
#        379513.68805881, 431344.95411827, 873714.02322301, 497376.01747595,
#        409188.09633002, 367964.75313777, 469758.00396044, 590035.78750968,
#        408030.34358704, 479882.95925178, 608254.27832114, 440647.58598584,
#        365742.45232159, 374539.1421375 , 425752.0203594 , 462236.21902814,
#        533014.58739739, 502159.04673071, 386506.88485068, 400635.98287798,
#        741207.09326146, 345822.19343885, 326676.75919485, 568063.20865061,
#        394615.90873136, 433086.1586489 , 410392.75299593, 387055.16890066,
#        843217.30638194, 739868.76006569, 489910.75309264, 400515.08614111,
#        843344.36327933, 468707.39035077, 501320.46343532, 766180.93757518,
#        336575.0819421 , 397650.10714014, 401795.66992452, 432488.88577875,
#        426643.41922262, 537164.48723652, 463869.70505093, 876394.11775932,
#        685378.75096553, 341036.39878185, 350925.32547577, 495010.90578782,
#        393673.6249875 , 328551.62679242, 612179.53237749, 602944.68144783,
#        625835.05775118, 623917.84829207, 606955.14494103, 698984.69116233,
#        414498.2017981 , 425422.58199624, 331225.67804363, 387413.10545814,
#        407131.65483343, 554875.51155137, 442687.72315992, 463396.93900207,
#        563093.38741063, 367003.18959789, 905525.42603743, 678172.29540939,
#        660057.81310449, 460277.18180345, 338967.00100252, 523332.25159169,
#        445362.20660957, 528368.46880105, 539512.27329876, 366128.67981311,
#        518608.26833189, 400875.96604879, 402926.08635202, 510748.38773956,
#        863859.80775826, 567590.0077623 , 706035.4852152 , 385583.29188472,
#        421524.93548981, 637434.57801755, 646908.61444514, 540765.3687388 ,
#        540168.37885009, 315687.83414009, 449048.74255705, 422752.20181519,
#        439942.33617283, 453336.19798876, 545853.15922616, 903371.93465849,
#        418307.66772283, 628224.65317592, 396901.46773155, 660883.4040118 ,
#        438423.15805688, 366681.76120048, 576430.91192714, 754809.83353922,
#        584876.78395145, 400537.24875708, 418818.31546637, 457631.79721354,
#        523187.73017699, 409328.06580436, 844229.94976674, 391633.92653236,
#        460284.30831468, 543723.08929684, 346761.75972928, 465724.2965489 ,
#        356410.24832055, 377309.90565746, 350867.27542711, 669269.77055729,
#        375863.941232  , 405397.02666218, 449575.61756427, 351856.78869946,
#        424778.73410571, 368241.27159353, 637745.69969343])

# %%
comparison_df=pd.DataFrame(
{'actual':y_test,
 'predicted': predicted
})
comparison_df
# Out:
#       actual      predicted
# 37    475900  469737.482650
# 129   440000  460664.515830
# 524   440000  460112.733495
# 1553  780000  764904.309005
# 1276  285000  371591.231191
# ...      ...            ...
# 114   500000  449575.617564
# 929   375000  351856.788699
# 658   400000  424778.734106
# 257   340000  368241.271594
# 2078  600000  637745.699693
#
# [567 rows x 2 columns]

# %%
pd.DataFrame(X_test)
# Out:
#         zip  Year Built  Bedrooms  Bathrooms  Approx SQFT  CrimeRate  \
# 37    85032        1972         3        2.0       1380.0        3.2
# 129   85041        2013         4        2.0       1681.0        4.5
# 524   85303        2002         3        2.5       1866.0        0.0
# 1553  85020        1993         4        2.5       2517.0        2.1
# 1276  85041        1949         4        2.0       1288.0        4.5
# ...     ...         ...       ...        ...          ...        ...
# 114   85006        1939         2        1.0        942.0        1.9
# 929   85043        1976         3        1.0       1192.0        3.2
# 658   85032        1974         3        2.0       1144.0        3.2
# 257   85033        2000         2        2.0        919.0        3.0
# 2078  85013        1947         3        2.0       1455.0        2.0
#
#       Hightest_Rated_School
# 37                    99.97
# 129                   76.54
# 524                   95.89
# 1553                  97.13
# 1276                  76.54
# ...                     ...
# 114                   94.44
# 929                   76.86
# 658                   99.97
# 257                   95.89
# 2078                  72.93
#
# [567 rows x 7 columns]

# %%
to_predict = [[85032.0, 2021, 2.0, 2.0, 3380.0, 4.0, 100.00]]

# %%
clf.predict(to_predict)
# Out:
# array([684977.51742341])

# %%
from pprint import pprint
# Look at parameters used by our current forest
print('Parameters currently in use:\n')
pprint(clf.get_params())
# Out:
# Parameters currently in use:
#
# {'bootstrap': False,
#  'ccp_alpha': 0.0,
#  'criterion': 'mse',
#  'max_depth': 20,
#  'max_features': 'sqrt',
#  'max_leaf_nodes': 700,
#  'max_samples': None,
#  'min_impurity_decrease': 0.0,
#  'min_impurity_split': None,
#  'min_samples_leaf': 2,
#  'min_samples_split': 2,
#  'min_weight_fraction_leaf': 0.0,
#  'n_estimators': 7272,
#  'n_jobs': None,
#  'oob_score': False,
#  'random_state': 78,
#  'verbose': 0,
#  'warm_start': False}

# %%
# plt.figure(figsize=(20,20))
# _ = tree.plot_tree(clf.estimators_[0], feature_names=X.columns, 
#                    filled=True, fontsize = 10)
# plt.show()

# %%
pickle.dump(clf,open('housepricepredictions.h5',"wb"))
