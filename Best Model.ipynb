# %%
# Importing necessary libraries
import numpy as np
import pandas as pd
import os
import joblib
import matplotlib.pyplot as plt
from sklearn import tree
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler,OneHotEncoder
import pickle

# %%
# Reading in the data
housing_df = pd.read_csv("combined_data_clean.csv")
housing_df.head()
# Out:
#    id   Price              Address    zip  status      mls  \
# 0   1  427167  3231 W MARYLAND AVE  85017  Active  6395749
# 1   2  400000     5109 E THOMAS RD  85018  Active  6243667
# 2   3  399900    8020 W STELLA AVE  85303  Active  6384821
# 3   4  349000      6944 W Verde LN  85033  Active  6395738
# 4   5  419000  4105 W PASADENA AVE  85019  Active  6395732
#
#                 Subdivision  Year Built  Bedrooms  Bathrooms  Approx SQFT  \
# 0  WEST PLAZA 6 LOT 614-787        1958         3        2.0       1302.0
# 1            PAPAGO VILLAGE        1943         0        0.0       1358.0
# 2                  SHALIMAR        1997         3        2.0       1505.0
# 3   MARYVALE TERRACE NO. 49        1983         3        3.0       1514.0
# 4            TU-DOR ESTATES        1971         4        2.0       1908.0
#
#    CrimeRate
# 0        4.1
# 1        2.2
# 2        0.0
# 3        3.0
# 4        2.5

# %%
# Check datatypes and make conversions if necessary
housing_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2265 entries, 0 to 2264
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   id           2265 non-null   int64
#  1   Price        2265 non-null   int64
#  2   Address      2265 non-null   object
#  3   zip          2265 non-null   int64
#  4   status       2265 non-null   object
#  5   mls          2265 non-null   int64
#  6   Subdivision  2261 non-null   object
#  7   Year Built   2265 non-null   int64
#  8   Bedrooms     2265 non-null   int64
#  9   Bathrooms    2265 non-null   float64
#  10  Approx SQFT  2265 non-null   float64
#  11  CrimeRate    2205 non-null   float64
# dtypes: float64(3), int64(6), object(3)
# memory usage: 212.5+ KB

# %%
# Interpolation
housing_df1 = housing_df.fillna(2.5)

# %%
# Checking the data again
housing_df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2265 entries, 0 to 2264
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   id           2265 non-null   int64
#  1   Price        2265 non-null   int64
#  2   Address      2265 non-null   object
#  3   zip          2265 non-null   int64
#  4   status       2265 non-null   object
#  5   mls          2265 non-null   int64
#  6   Subdivision  2265 non-null   object
#  7   Year Built   2265 non-null   int64
#  8   Bedrooms     2265 non-null   int64
#  9   Bathrooms    2265 non-null   float64
#  10  Approx SQFT  2265 non-null   float64
#  11  CrimeRate    2265 non-null   float64
# dtypes: float64(3), int64(6), object(3)
# memory usage: 212.5+ KB

# %%
education_df = pd.read_csv("education_by_zip.csv")
education_df.head()
education_df.rename(columns={'Zip':'zip'},inplace=True)
education_df.head()
# Out:
#      zip Elem_School_District  Hightest_Rated_School
# 0  85003   Phoenix Elementary                  94.44
# 1  85004   Phoenix Elementary                  94.44
# 2  85006   Phoenix Elementary                  94.44
# 3  85007   Phoenix Elementary                  94.44
# 4  85008                Balsz                  81.79

# %%
housing_df1.drop_duplicates()
# Out:
#         id   Price               Address    zip  status      mls  \
# 0        1  427167   3231 W MARYLAND AVE  85017  Active  6395749
# 1        2  400000      5109 E THOMAS RD  85018  Active  6243667
# 2        3  399900     8020 W STELLA AVE  85303  Active  6384821
# 3        4  349000       6944 W Verde LN  85033  Active  6395738
# 4        5  419000   4105 W PASADENA AVE  85019  Active  6395732
# ...    ...     ...                   ...    ...     ...      ...
# 2260  2311  600000  3402 E CAROL ANN WAY  85032  Closed  6368329
# 2261  2312  375000   739 E Constance WAY  85042  Closed  6358973
# 2262  2313  365000      7301 W CHERYL DR  85345  Closed  6365681
# 2263  2314  529000     4637 E GRANADA RD  85008  Closed  6354718
# 2264  2315  460000       2016 W HOLLY ST  85009  Closed  6362564
#
#                    Subdivision  Year Built  Bedrooms  Bathrooms  Approx SQFT  \
# 0     WEST PLAZA 6 LOT 614-787        1958         3        2.0       1302.0
# 1               PAPAGO VILLAGE        1943         0        0.0       1358.0
# 2                     SHALIMAR        1997         3        2.0       1505.0
# 3      MARYVALE TERRACE NO. 49        1983         3        3.0       1514.0
# 4               TU-DOR ESTATES        1971         4        2.0       1908.0
# ...                        ...         ...       ...        ...          ...
# 2260               BELLA TERRA        1981         3        2.0       2012.0
# 2261        VILLAGES AT VERONA        2016         3        2.5       1499.0
# 2262            SUNTOWN UNIT 2        1972         3        2.0       1581.0
# 2263                RANCHO MIO        1953         3        2.0       1710.0
# 2264                    VENICE        1953         3        2.0       1145.0
#
#       CrimeRate
# 0           4.1
# 1           2.2
# 2           0.0
# 3           3.0
# 4           2.5
# ...         ...
# 2260        3.2
# 2261        2.9
# 2262        0.0
# 2263        4.5
# 2264        4.0
#
# [2265 rows x 12 columns]

# %%
merged_df=housing_df1.merge(education_df, how='left', on='zip')
merged_df
# Out:
#         id   Price               Address    zip  status      mls  \
# 0        1  427167   3231 W MARYLAND AVE  85017  Active  6395749
# 1        2  400000      5109 E THOMAS RD  85018  Active  6243667
# 2        3  399900     8020 W STELLA AVE  85303  Active  6384821
# 3        4  349000       6944 W Verde LN  85033  Active  6395738
# 4        5  419000   4105 W PASADENA AVE  85019  Active  6395732
# ...    ...     ...                   ...    ...     ...      ...
# 2260  2311  600000  3402 E CAROL ANN WAY  85032  Closed  6368329
# 2261  2312  375000   739 E Constance WAY  85042  Closed  6358973
# 2262  2313  365000      7301 W CHERYL DR  85345  Closed  6365681
# 2263  2314  529000     4637 E GRANADA RD  85008  Closed  6354718
# 2264  2315  460000       2016 W HOLLY ST  85009  Closed  6362564
#
#                    Subdivision  Year Built  Bedrooms  Bathrooms  Approx SQFT  \
# 0     WEST PLAZA 6 LOT 614-787        1958         3        2.0       1302.0
# 1               PAPAGO VILLAGE        1943         0        0.0       1358.0
# 2                     SHALIMAR        1997         3        2.0       1505.0
# 3      MARYVALE TERRACE NO. 49        1983         3        3.0       1514.0
# 4               TU-DOR ESTATES        1971         4        2.0       1908.0
# ...                        ...         ...       ...        ...          ...
# 2260               BELLA TERRA        1981         3        2.0       2012.0
# 2261        VILLAGES AT VERONA        2016         3        2.5       1499.0
# 2262            SUNTOWN UNIT 2        1972         3        2.0       1581.0
# 2263                RANCHO MIO        1953         3        2.0       1710.0
# 2264                    VENICE        1953         3        2.0       1145.0
#
#       CrimeRate     Elem_School_District  Hightest_Rated_School
# 0           4.1                 Alhambra                 100.04
# 1           2.2                Creighton                  75.80
# 2           0.0               Cartwright                  95.89
# 3           3.0               Cartwright                  95.89
# 4           2.5                 Alhambra                 100.04
# ...         ...                      ...                    ...
# 2260        3.2  Paradise Valley Unified                  99.97
# 2261        2.9                Roosevelt                  76.54
# 2262        0.0               Pendergast                  85.28
# 2263        4.5                    Balsz                  81.79
# 2264        4.0                   Murphy                  65.70
#
# [2265 rows x 14 columns]

# %%
new_housing_df=merged_df.drop(columns=['mls','Address','id','Subdivision','status','Elem_School_District'
                                      ],axis=1)
new_housing_df
# Out:
#        Price    zip  Year Built  Bedrooms  Bathrooms  Approx SQFT  CrimeRate  \
# 0     427167  85017        1958         3        2.0       1302.0        4.1
# 1     400000  85018        1943         0        0.0       1358.0        2.2
# 2     399900  85303        1997         3        2.0       1505.0        0.0
# 3     349000  85033        1983         3        3.0       1514.0        3.0
# 4     419000  85019        1971         4        2.0       1908.0        2.5
# ...      ...    ...         ...       ...        ...          ...        ...
# 2260  600000  85032        1981         3        2.0       2012.0        3.2
# 2261  375000  85042        2016         3        2.5       1499.0        2.9
# 2262  365000  85345        1972         3        2.0       1581.0        0.0
# 2263  529000  85008        1953         3        2.0       1710.0        4.5
# 2264  460000  85009        1953         3        2.0       1145.0        4.0
#
#       Hightest_Rated_School
# 0                    100.04
# 1                     75.80
# 2                     95.89
# 3                     95.89
# 4                    100.04
# ...                     ...
# 2260                  99.97
# 2261                  76.54
# 2262                  85.28
# 2263                  81.79
# 2264                  65.70
#
# [2265 rows x 8 columns]

# %%
# creating a new csv file named ml_model.
new_housing_df.to_csv("ml_model_data.csv", index=False)

# %%
# Split our preprocessed data into our features and target arrays
#y = new_housing_df["Price"].values
y = new_housing_df["Price"]
#X = new_housing_df.drop(["Price"],axis=1).values
X = new_housing_df.drop(["Price"],axis=1)
X
# Out:
#         zip  Year Built  Bedrooms  Bathrooms  Approx SQFT  CrimeRate  \
# 0     85017        1958         3        2.0       1302.0        4.1
# 1     85018        1943         0        0.0       1358.0        2.2
# 2     85303        1997         3        2.0       1505.0        0.0
# 3     85033        1983         3        3.0       1514.0        3.0
# 4     85019        1971         4        2.0       1908.0        2.5
# ...     ...         ...       ...        ...          ...        ...
# 2260  85032        1981         3        2.0       2012.0        3.2
# 2261  85042        2016         3        2.5       1499.0        2.9
# 2262  85345        1972         3        2.0       1581.0        0.0
# 2263  85008        1953         3        2.0       1710.0        4.5
# 2264  85009        1953         3        2.0       1145.0        4.0
#
#       Hightest_Rated_School
# 0                    100.04
# 1                     75.80
# 2                     95.89
# 3                     95.89
# 4                    100.04
# ...                     ...
# 2260                  99.97
# 2261                  76.54
# 2262                  85.28
# 2263                  81.79
# 2264                  65.70
#
# [2265 rows x 7 columns]

# %%
len(X['zip'].unique())
# Out:
# 47

# %%
len(X['CrimeRate'].unique())
# Out:
# 26

# %%
len(X['Hightest_Rated_School'].unique())
# Out:
# 17

# %%
# df=pd.DataFrame(columns=['zip','CrimeRate','Hightest_Rated_School'])
# for zipcode in X['zip'].unique():
#     df.append(X.loc[X['zip']=='zipcode'])

# %%
# loaded_model = pickle.load(open('housepricepredictions.h5','rb'))

# %%
# loaded_model.predict(X)
# Out:
# array([397520.81063452, 475684.74019872, 404312.77569586, ...,
#        391185.49741305, 548358.21278111, 408188.65531644])

# %%
# df_zip=X.loc[(X['zip']==zip)]

# %%
# df_zip

# %%
# ZipCrimeSchool=pd.concat([zipcode_crime_school['zip'],zipcode_crime_school['CrimeRate'],zipcode_crime_school['Hightest_Rated_School']],axis=1).unique()
# pd.DataFrame(ZipCrimeSchool)

# %%
# i=0
# df=pd.DataFrame()
# for col in zipcode_crime_school:
   
#     print(col)
   
#     df[i]=zipcode_crime_school[f'{col}'].unique()
#     i+=1
# df

# %%
zip_list=[]
zip_crime_school={}
for zip in X['zip']:
    if zip not in zip_list:
        zip_list.append(zip)
   
        zip_crime_school['school_rating']=X.groupby(['zip']).mean()['Hightest_Rated_School'] 
        zip_crime_school['crime_rate']=X.groupby(['zip']).mean()['CrimeRate']

zip_school_crime_df = pd.DataFrame.from_dict(zip_crime_school)
zip_school_crime_df.head(10)
# Out:
#        school_rating  crime_rate
# zip
# 85003          94.44         1.1
# 85004          94.44         1.2
# 85006          94.44         1.9
# 85007          94.44         1.6
# 85008          81.79         4.5
# 85009          65.70         4.0
# 85012          72.93         0.6
# 85013          72.93         2.0
# 85014          97.13         1.9
# 85015         100.04         5.5

# %%
new_zip_crime_school=pd.DataFrame.to_dict(zip_school_crime_df)

# %%
new_zip_crime_school
# Out:
# {'school_rating': {85003: 94.44,
#   85004: 94.44,
#   85006: 94.44,
#   85007: 94.44,
#   85008: 81.79,
#   85009: 65.7,
#   85012: 72.93,
#   85013: 72.93,
#   85014: 97.13000000000001,
#   85015: 100.04000000000002,
#   85016: 97.13,
#   85017: 100.04,
#   85018: 75.8,
#   85019: 100.04,
#   85020: 97.13,
#   85021: 91.9,
#   85022: 99.97,
#   85023: 91.9,
#   85028: 99.97,
#   85029: 91.9,
#   85031: 100.04,
#   85032: 99.97,
#   85033: 95.89,
#   85034: 68.34,
#   85035: 95.89,
#   85037: 85.28,
#   85040: 76.54,
#   85041: 76.54,
#   85042: 76.54,
#   85043: 76.86,
#   85051: 91.9,
#   85053: 91.9,
#   85250: 101.35,
#   85251: 101.35,
#   85254: 99.97,
#   85257: 101.34999999999998,
#   85258: 101.34999999999998,
#   85281: 94.49,
#   85282: 94.49,
#   85301: 100.04,
#   85302: 91.9,
#   85303: 95.89,
#   85304: 91.9,
#   85305: 85.28,
#   85306: 91.9,
#   85339: 94.47,
#   85345: 85.28},
#  'crime_rate': {85003: 1.1,
#   85004: 1.2,
#   85006: 1.9,
#   85007: 1.6,
#   85008: 4.5,
#   85009: 4.0,
#   85012: 0.6,
#   85013: 2.0,
#   85014: 1.9,
#   85015: 5.5,
#   85016: 3.2,
#   85017: 4.1,
#   85018: 2.2,
#   85019: 2.5,
#   85020: 2.1,
#   85021: 2.8,
#   85022: 2.6,
#   85023: 3.4,
#   85028: 0.6,
#   85029: 3.3,
#   85031: 2.4,
#   85032: 3.1999999999999997,
#   85033: 3.0,
#   85034: 1.8999999999999997,
#   85035: 3.3,
#   85037: 1.9,
#   85040: 2.8,
#   85041: 4.5,
#   85042: 2.9,
#   85043: 3.2,
#   85051: 4.3,
#   85053: 1.5,
#   85250: 2.5,
#   85251: 0.0,
#   85254: 1.1,
#   85257: 2.5,
#   85258: 0.0,
#   85281: 0.0,
#   85282: 0.0,
#   85301: 0.0,
#   85302: 0.0,
#   85303: 0.0,
#   85304: 0.2,
#   85305: 2.5,
#   85306: 0.3,
#   85339: 2.0,
#   85345: 0.0}}

# %%
zip_crime_school
# Out:
# {'school_rating': zip
#  85003     94.44
#  85004     94.44
#  85006     94.44
#  85007     94.44
#  85008     81.79
#  85009     65.70
#  85012     72.93
#  85013     72.93
#  85014     97.13
#  85015    100.04
#  85016     97.13
#  85017    100.04
#  85018     75.80
#  85019    100.04
#  85020     97.13
#  85021     91.90
#  85022     99.97
#  85023     91.90
#  85028     99.97
#  85029     91.90
#  85031    100.04
#  85032     99.97
#  85033     95.89
#  85034     68.34
#  85035     95.89
#  85037     85.28
#  85040     76.54
#  85041     76.54
#  85042     76.54
#  85043     76.86
#  85051     91.90
#  85053     91.90
#  85250    101.35
#  85251    101.35
#  85254     99.97
#  85257    101.35
#  85258    101.35
#  85281     94.49
#  85282     94.49
#  85301    100.04
#  85302     91.90
#  85303     95.89
#  85304     91.90
#  85305     85.28
#  85306     91.90
#  85339     94.47
#  85345     85.28
#  Name: Hightest_Rated_School, dtype: float64,
#  'crime_rate': zip
#  85003    1.1
#  85004    1.2
#  85006    1.9
#  85007    1.6
#  85008    4.5
#  85009    4.0
#  85012    0.6
#  85013    2.0
#  85014    1.9
#  85015    5.5
#  85016    3.2
#  85017    4.1
#  85018    2.2
#  85019    2.5
#  85020    2.1
#  85021    2.8
#  85022    2.6
#  85023    3.4
#  85028    0.6
#  85029    3.3
#  85031    2.4
#  85032    3.2
#  85033    3.0
#  85034    1.9
#  85035    3.3
#  85037    1.9
#  85040    2.8
#  85041    4.5
#  85042    2.9
#  85043    3.2
#  85051    4.3
#  85053    1.5
#  85250    2.5
#  85251    0.0
#  85254    1.1
#  85257    2.5
#  85258    0.0
#  85281    0.0
#  85282    0.0
#  85301    0.0
#  85302    0.0
#  85303    0.0
#  85304    0.2
#  85305    2.5
#  85306    0.3
#  85339    2.0
#  85345    0.0
#  Name: CrimeRate, dtype: float64}

# %%
# Split the preprocessed data into a training and testing dataset
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=78)

# %%
clf2 = RandomForestRegressor(n_estimators = 1000, min_samples_split = 2, min_samples_leaf = 2, max_leaf_nodes = 700,
                            max_features = 'sqrt', max_depth = 20, bootstrap = True, random_state = 100)
clf2.fit(X_train, y_train)
# Out:
# RandomForestRegressor(max_depth=20, max_features='sqrt', max_leaf_nodes=700,
#                       min_samples_leaf=2, n_estimators=1000, random_state=100)

# %%
print(f'Training Score: {clf2.score(X_train, y_train)}')
print(f'Testing Score: {clf2.score(X_test, y_test)}')
# Out:
# Training Score: 0.8946543645072609
# Testing Score: 0.7431482574079082

# %%
joblib.dump(clf2, 'final_model.joblib', compress=3)
# Out:
# ['final_model.joblib']

# %%
loaded_clf=joblib.load('final_model.joblib')

# %%
os.path.getsize('final_model.joblib') / 1024 / 1024
# Out:
# 15.177127838134766

# %%
print(f'Training Score: {loaded_clf.score(X_train, y_train)}')
print(f'Testing Score: {loaded_clf.score(X_test, y_test)}')
# Out:
# Training Score: 0.8946543645072609
# Testing Score: 0.7431482574079082

# %%
predicted=clf2.predict(X_test)
predicted
# Out:
# array([475113.1356976 , 459994.12291039, 467755.80955147, 780834.63299415,
#        373583.82902031, 671894.99411382, 547182.33093432, 571431.36326044,
#        378895.06990322, 345481.62334055, 500334.9094422 , 450483.38776429,
#        415273.03754484, 367050.05164219, 614322.11078405, 512640.92798175,
#        559382.26159555, 710890.64121745, 325436.69104076, 566172.99489072,
#        846765.94025018, 519115.45285231, 458288.82877784, 455895.76830344,
#        718757.61145508, 345929.84826998, 736513.55857269, 517665.59395971,
#        404015.00748716, 685231.78733732, 395999.32351112, 757036.3641964 ,
#        376471.93591182, 405125.83402311, 534056.69860654, 633569.51226637,
#        324422.46380596, 348001.15748289, 374727.61642921, 490073.1722576 ,
#        527734.78242929, 713929.38544706, 637671.57467688, 400684.71436653,
#        777282.99872735, 377279.6255803 , 373020.2119987 , 450317.09719154,
#        495230.00830952, 380305.48158917, 296073.77159131, 341762.12028551,
#        462069.75494034, 429436.82905674, 611531.55141917, 804067.0632925 ,
#        572220.05881345, 386203.77576178, 729149.94620814, 518386.93249298,
#        641772.10422694, 417668.6492358 , 806398.99343835, 482116.27750023,
#        326306.9944584 , 356901.20985103, 644250.62032704, 452577.36012833,
#        461492.25928412, 400482.38025731, 818018.92089867, 497611.44559951,
#        744126.44697595, 419355.37861631, 453718.81559034, 617095.43141997,
#        668976.16088059, 561931.35791543, 386395.68657318, 444356.67818832,
#        360327.423313  , 871792.32762736, 587710.75166297, 386043.61861429,
#        488023.51860745, 423752.50462337, 479929.41007848, 575813.10820509,
#        631867.76791586, 713357.74168832, 404871.72688003, 723496.79982179,
#        367695.06943753, 675670.86200286, 508644.41595369, 531386.04140376,
#        378713.94764591, 450625.6667132 , 840028.55837419, 495431.55412183,
#        410328.72833706, 369730.64384863, 468554.40370492, 602184.74443576,
#        402681.63901055, 483675.0868035 , 596009.03254471, 443171.69879965,
#        371155.37838377, 416204.10937772, 423549.18355916, 496920.16869421,
#        569018.88724586, 499521.14746569, 390524.48758191, 405957.51304275,
#        723424.59508981, 355143.39018096, 339582.30527202, 563564.63836351,
#        401528.85552619, 435583.85235069, 410733.82884327, 394311.53701587,
#        828976.02803253, 737578.39069869, 495099.99755424, 400069.72900895,
#        824002.45529818, 465438.05176698, 507450.7438582 , 773959.24671187,
#        347056.21091763, 397885.22572899, 400498.63456562, 434376.78994016,
#        437105.03504214, 527734.28594555, 464322.77533342, 862234.03549497,
#        692918.71217813, 341546.69995537, 353542.31680018, 489573.28511309,
#        392202.09752275, 326576.77283279, 628978.97561649, 568068.91026627,
#        347061.2848101 , 594780.78330783, 561399.67538517, 544698.10889305,
#        553224.74377054, 667447.95666967, 504791.87618044, 411186.21848723,
#        558722.56702469, 367174.3708752 , 863261.36219236, 675208.44024774,
#        646328.26327647, 435756.1794972 , 342153.86770841, 542818.48847701,
#        441046.61758693, 540497.98260982, 545754.24392685, 366212.53201401,
#        511419.15870753, 401971.52146477, 408430.34935852, 512257.42802073,
#        857563.46238457, 557511.32406563, 703550.44335907, 387368.10329449,
#        428123.30786652, 632523.13369985, 652368.30460491, 544042.55523376,
#        558490.21248036, 325528.33984437, 477582.08502719, 429343.55635775,
#        443419.51680662, 444065.90977746, 547639.88363575, 900438.04451397,
#        418935.47353588, 627456.3074152 , 399629.1658523 , 648303.59453038,
#        448073.37089935, 371818.1732463 , 598115.90034288, 768470.24164594,
#        585586.28575901, 410978.21842765, 434277.47865083, 453239.480535  ,
#        541028.32465321, 411654.83972286, 825324.53045116, 390427.7095903 ,
#        448827.09147481, 550176.24472848, 359193.42155334, 462107.12440153,
#        357188.94170792, 382930.25905592, 355832.02105711, 680405.60165218,
#        376279.08705051, 413640.31335525, 438755.97893358, 352165.4576387 ,
#        438117.49507357, 366879.34948303, 622745.54080413])

# %%
comparison_df=pd.DataFrame(
{'actual':y_test,
 'predicted': predicted
})
comparison_df
# Out:
#       actual      predicted
# 37    475900  475113.135698
# 129   440000  459994.122910
# 524   440000  467755.809551
# 1553  780000  780834.632994
# 1276  285000  373583.829020
# ...      ...            ...
# 114   500000  438755.978934
# 929   375000  352165.457639
# 658   400000  438117.495074
# 257   340000  366879.349483
# 2078  600000  622745.540804
#
# [567 rows x 2 columns]

# %%
pd.DataFrame(X_test)
# Out:
#         zip  Year Built  Bedrooms  Bathrooms  Approx SQFT  CrimeRate  \
# 37    85032        1972         3        2.0       1380.0        3.2
# 129   85041        2013         4        2.0       1681.0        4.5
# 524   85303        2002         3        2.5       1866.0        0.0
# 1553  85020        1993         4        2.5       2517.0        2.1
# 1276  85041        1949         4        2.0       1288.0        4.5
# ...     ...         ...       ...        ...          ...        ...
# 114   85006        1939         2        1.0        942.0        1.9
# 929   85043        1976         3        1.0       1192.0        3.2
# 658   85032        1974         3        2.0       1144.0        3.2
# 257   85033        2000         2        2.0        919.0        3.0
# 2078  85013        1947         3        2.0       1455.0        2.0
#
#       Hightest_Rated_School
# 37                    99.97
# 129                   76.54
# 524                   95.89
# 1553                  97.13
# 1276                  76.54
# ...                     ...
# 114                   94.44
# 929                   76.86
# 658                   99.97
# 257                   95.89
# 2078                  72.93
#
# [567 rows x 7 columns]

# %%
to_predict = [[85032.0, 2021, 2.0, 2.0, 3380.0, 4.0, 100.00]]

# %%
clf2.predict(to_predict)
# Out:
# array([655768.44692129])

# %%
from pprint import pprint
# Look at parameters used by our current forest
print('Parameters currently in use:\n')
pprint(clf2.get_params())
# Out:
# Parameters currently in use:
#
# {'bootstrap': True,
#  'ccp_alpha': 0.0,
#  'criterion': 'mse',
#  'max_depth': 20,
#  'max_features': 'sqrt',
#  'max_leaf_nodes': 700,
#  'max_samples': None,
#  'min_impurity_decrease': 0.0,
#  'min_impurity_split': None,
#  'min_samples_leaf': 2,
#  'min_samples_split': 2,
#  'min_weight_fraction_leaf': 0.0,
#  'n_estimators': 1000,
#  'n_jobs': None,
#  'oob_score': False,
#  'random_state': 100,
#  'verbose': 0,
#  'warm_start': False}

# %%
# plt.figure(figsize=(20,20))
# _ = tree.plot_tree(clf.estimators_[0], feature_names=X.columns, 
#                    filled=True, fontsize = 10)
# plt.show()
